# %% [markdown]
# <a href="https://colab.research.google.com/github/lemarzubaidi/python-ML/blob/main/train%26test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#from google.colab import files
#uploded=files.upload()


#from google.colab import drive
#drive.mount('/content/....')


#df=pd.read_csv("")
#df

# %% [markdown]
# split Dataset

# %%
#features and target
x=df["name of col featur"]
y=df["name of col tar"]
#split data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_929/2745510779.py in <cell line: 0>()
#       1 #features and target
# ----> 2 x=df["name of col featur"]
#       3 y=df["name of col tar"]
#       4 #split data
#       5 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Train Model

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)#for train
#Prediction
y_pred=model.predict(x_test)

# %% [markdown]
# **Evaluation**

# %%
print("Accuracy: ",accuracy_score(y_test,y_pred))
print("Precision: ",precision_score(y_test,y_pred))
print("Recall: ",recall_score(y_test,y_pred))
print("F1-Score: ",f1_score(y_test,y_pred))
print("\nConfusion Matrix:\n: ",confusion_matrix(y_test,y_pred))

# %%
#confusion matrix use sns
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
plt.xlable("predicted")
plt.ylable("Actual")
plt.title("confusion Matrix")
