# %% [markdown]
# <a href="https://colab.research.google.com/github/lemarzubaidi/python/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips['total_bill'],kde=True)
plt.show()

# %%
sns.displot(tips['total_bill'],kde=False)
plt.show()

# %%
sns.displot(tips['total_bill'],bins=5)
plt.show()

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')
plt.show()

# %%
sns.lineplot(data=tips,x='day',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(tips)

# %%
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.heatmap(tips.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 #Grids & Regression
 #FaceGrid
 g = sns.FacetGrid(tips,col="time",row="sex")
 g.map(sns.scatterplot,"total_bill","tip")

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',col_wrap=2)
